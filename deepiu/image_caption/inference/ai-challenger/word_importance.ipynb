# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
flags = tf.app.flags
FLAGS = flags.FLAGS

import os
import gezi, melt
from deepiu.util import ids2text
from libgezi import utf82gbk, gbk2utf8

# %matplotlib inline
import matplotlib.pyplot as plt

#from IPython.display import Image
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
# Out:
# tensorflow_version: 1.2.0-rc0
# Warning: no conf.py in current path use util conf
# Warning, no conf.py in current path use util conf
# Warning: no conf.py in current path use util conf

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:10000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:10000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
from pandas import DataFrame 
import pandas as pd 
import matplotlib.pyplot as plt 
from matplotlib.font_manager import FontProperties 

font = FontProperties(fname="/home/gezi/soft/simsunttc/msyh.ttf", size=12)  #size可不用指定

# %%
model_dir = '/home/gezi/new/temp/image-caption/ai-challenger/model/bow/'
predictor = melt.WordsImportancePredictor(model_dir)
# Out:
# INFO:tensorflow:Restoring parameters from /home/gezi/new/temp/image-caption/ai-challenger/model/bow/model.ckpt-46.3-190000
# restore meta grpah and model ok /home/gezi/new/temp/image-caption/ai-challenger/model/bow/model.ckpt-46.3-190000

# %%
texts, scores = predictor.predict(feature)
print(texts, scores)
# Out:
# [[[722  16  11 ...,   9   9   9]
#   [722  16  11 ...,   9   9   9]
#   [722  16  11 ...,   9   9   9]
#   ...,
#   [722  16  11 ...,   9   9   9]
#   [722  16  11 ...,   9   9   9]
#   [  4   2  43 ...,   9   9   9]]] [[ 0.54633152  0.53853232  0.51950175  0.51906222  0.51791531  0.51271182
#    0.50794113  0.50726646  0.50406516  0.48545688]]

# %%
image_show(image_path)
texts = texts[0]
scores = scores[0]
for text, score in zip(texts, scores):
    print(gbk2utf8(ids2text.ids2text(text)), score)
    print(gbk2utf8(ids2text.translate(text)), score)
# Out:
# 田地/里/有/一/个/双手/拿/着/工具/的/男人/在/干活/</S> 0.546332
# 田地里有一个双手拿着工具的男人在干活 0.546332
# 田地/里/有/一/个/右手/拿/着/工具/的/男人/在/干活/</S> 0.538532
# 田地里有一个右手拿着工具的男人在干活 0.538532
# 田地/里/有/一/个/穿/着/蓝色/上衣/的/男人/在/干活/</S> 0.519502
# 田地里有一个穿着蓝色上衣的男人在干活 0.519502
# 田地/里/有/一/个/双手/拿/着/东西/的/男人/在/干活/</S> 0.519062
# 田地里有一个双手拿着东西的男人在干活 0.519062
# 田地/里/有/一/个/右手/拿/着/工具/的/女人/在/干活/</S> 0.517915
# 田地里有一个右手拿着工具的女人在干活 0.517915
# 田地/里/有/一/个/穿/着/红色/上衣/的/男人/在/干活/</S> 0.512712
# 田地里有一个穿着红色上衣的男人在干活 0.512712
# 田地/里/有/一/个/穿/着/深色/上衣/的/男人/在/干活/</S> 0.507941
# 田地里有一个穿着深色上衣的男人在干活 0.507941
# 田地/里/有/一/个/穿/着/红色/上衣/的/女人/在/干活/</S> 0.507266
# 田地里有一个穿着红色上衣的女人在干活 0.507266
# 田地/里/有/一/个/穿/着/蓝色/上衣/的/女人/在/干活/</S> 0.504065
# 田地里有一个穿着蓝色上衣的女人在干活 0.504065
# 一/个/右手/拿/着/工具/的/男人/在/田地/里/干活/</S> 0.485457
# 一个右手拿着工具的男人在田地里干活 0.485457
